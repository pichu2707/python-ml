# %% [markdown]
# # Resumen de los datos: dimensiones y estructuras

# %%
import numpy as np
import pandas as pd

# %%
mainpath = "C:/Users/Megaport/Desktop/python/datos machine learning/python-ml-course-master/datasets"
filename = "titanic/titanic3.csv"
fullpath = mainpath + "/" + filename

# %%
data = pd.read_csv(fullpath)

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
#Coge los datos desde abajo
data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
#coge los datos (filas, columnas)
data.shape
# Out:
# (1309, 14)

# %%
#datos de las columnas
data.columns.values
# Out:
# array(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype=object)

# %% [markdown]
# Ahora vamos a hacer un resumen de los estadísiticos básicos de las variables numéricas

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# # Cuando faltan valores

# %%
#Tenemos la edad de 1046 personas por ejemplo, pero son 1309 los datos que tenemos,
#con lo que quiere decir que nos faltan valores en diferentes columnas.
#Ahora vamos a ver como podemos comprobar si están o no los datos y como tratarlos.
pd.isnull(data["body"])
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10      False
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25      False
# 26       True
# 27       True
# 28       True
# 29       True
#         ...
# 1279     True
# 1280     True
# 1281     True
# 1282     True
# 1283     True
# 1284     True
# 1285    False
# 1286     True
# 1287     True
# 1288    False
# 1289     True
# 1290     True
# 1291     True
# 1292     True
# 1293     True
# 1294    False
# 1295     True
# 1296    False
# 1297     True
# 1298     True
# 1299     True
# 1300     True
# 1301    False
# 1302     True
# 1303     True
# 1304    False
# 1305     True
# 1306    False
# 1307     True
# 1308     True
# ...

# %%
#y ahora el caso contrario
pd.notnull(data["body"])
# Out:
# 0       False
# 1       False
# 2       False
# 3        True
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9        True
# 10       True
# 11      False
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25       True
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1279    False
# 1280    False
# 1281    False
# 1282    False
# 1283    False
# 1284    False
# 1285     True
# 1286    False
# 1287    False
# 1288     True
# 1289    False
# 1290    False
# 1291    False
# 1292    False
# 1293    False
# 1294     True
# 1295    False
# 1296     True
# 1297    False
# 1298    False
# 1299    False
# 1300    False
# 1301     True
# 1302    False
# 1303    False
# 1304     True
# 1305    False
# 1306     True
# 1307    False
# 1308    False
# ...

# %%
pd.isnull(data["body"]).values.ravel().sum()
# Out:
# 1188

# %%
pd.notnull(data["body"]).values.ravel().sum()
# Out:
# 121

# %% [markdown]
# Los valores que falatan en un data set pueden venir por dos razones:
# * Extración de los datos
# * Recolección de los datos

# %% [markdown]
# ### borrado de valores que faltan

# %%
#solo borra si todas y cada una de las columnas son NaN
data.dropna(axis=0, how='all')
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data2 = data

# %%
#Borra todo lo que contenga al menos un NaN
data2.dropna(axis=0, how='any')
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %% [markdown]
# ### Cómputo de los valores faltantes

# %%
data3 = data

# %%
#Rellena los datos que faltan con un 0
data3.fillna(0)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data4 = data

# %%
#Nos cambia los NaN por Desconocido
data4.fillna("Desconocido")
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
data5 = data

# %%
#Cambia los body con NaN por 0
#y los home.dest con NaN con Desconocido
data5["body"]= data5["body"].fillna(0)
data5["home.dest"] = data5["home.dest"].fillna("Desconocido")
data5.tail(20)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1289       3         0                  Wiklund, Mr. Karl Johan    male  21.0
# 1290       3         1         Wilkes, Mrs. James (Ellen Needs)  female  47.0
# 1291       3         0         Willer, Mr. Aaron ("Abi Weller")    male   NaN
# 1292       3         0                       Willey, Mr. Edward    male   NaN
# 1293       3         0        Williams, Mr. Howard Hugh "Harry"    male   NaN
# 1294       3         0                     Williams, Mr. Leslie    male  28.5
# 1295       3         0                      Windelov, Mr. Einar    male  21.0
# 1296       3         0                         Wirz, Mr. Albert    male  27.0
# 1297       3         0                   Wiseman, Mr. Phillippe    male   NaN
# 1298       3         0                Wittevrongel, Mr. Camille    male  36.0
# 1299       3         0                      Yasbeck, Mr. Antoni    male  27.0
# ...

# %%
pd.isnull(data5["age"]).values.ravel().sum()
# Out:
# 263

# %%
#Te da un promedio 
data5["age"].fillna(data["age"].mean())
# Out:
# 0       29.000000
# 1        0.916700
# 2        2.000000
# 3       30.000000
# 4       25.000000
# 5       48.000000
# 6       63.000000
# 7       39.000000
# 8       53.000000
# 9       71.000000
# 10      47.000000
# 11      18.000000
# 12      24.000000
# 13      26.000000
# 14      80.000000
# 15      29.881135
# 16      24.000000
# 17      50.000000
# 18      32.000000
# 19      36.000000
# 20      37.000000
# 21      47.000000
# 22      26.000000
# 23      42.000000
# 24      29.000000
# 25      25.000000
# 26      25.000000
# 27      19.000000
# 28      35.000000
# 29      28.000000
#           ...
# 1279    14.000000
# 1280    22.000000
# 1281    22.000000
# 1282    29.881135
# 1283    29.881135
# 1284    29.881135
# 1285    32.500000
# 1286    38.000000
# 1287    51.000000
# 1288    18.000000
# 1289    21.000000
# 1290    47.000000
# 1291    29.881135
# 1292    29.881135
# 1293    29.881135
# 1294    28.500000
# 1295    21.000000
# 1296    27.000000
# 1297    29.881135
# ...

# %%
#ahora tenemos para remplazar los valores con el que encuentre con el más cerca del mismo hay para hacerlo con el anterior 
#o el dato posterior
data["age"][1291]
# Out:
# nan

# %%
data5["age"].fillna(method="backfill")
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
# 5       48.0000
# 6       63.0000
# 7       39.0000
# 8       53.0000
# 9       71.0000
# 10      47.0000
# 11      18.0000
# 12      24.0000
# 13      26.0000
# 14      80.0000
# 15      24.0000
# 16      24.0000
# 17      50.0000
# 18      32.0000
# 19      36.0000
# 20      37.0000
# 21      47.0000
# 22      26.0000
# 23      42.0000
# 24      29.0000
# 25      25.0000
# 26      25.0000
# 27      19.0000
# 28      35.0000
# 29      28.0000
#          ...
# 1279    14.0000
# 1280    22.0000
# 1281    22.0000
# 1282    32.5000
# 1283    32.5000
# 1284    32.5000
# 1285    32.5000
# 1286    38.0000
# 1287    51.0000
# 1288    18.0000
# 1289    21.0000
# 1290    47.0000
# 1291    28.5000
# 1292    28.5000
# 1293    28.5000
# 1294    28.5000
# 1295    21.0000
# 1296    27.0000
# 1297    36.0000
# 1298    36.0000
# 1299    27.0000
# 1300    15.0000
# 1301    45.5000
# 1302    14.5000
# ...

# %% [markdown]
# ## Variables Dummy

# %%
data["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
# 5         male
# 6       female
# 7         male
# 8       female
# 9         male
# 10        male
# 11      female
# 12      female
# 13      female
# 14        male
# 15        male
# 16        male
# 17      female
# 18      female
# 19        male
# 20        male
# 21      female
# 22        male
# 23      female
# 24      female
# 25        male
# 26        male
# 27      female
# 28      female
# 29        male
#          ...
# 1279    female
# 1280      male
# 1281      male
# 1282      male
# 1283      male
# 1284      male
# 1285      male
# 1286    female
# 1287      male
# 1288      male
# 1289      male
# 1290    female
# 1291      male
# 1292      male
# 1293      male
# 1294      male
# 1295      male
# 1296      male
# 1297      male
# 1298      male
# 1299      male
# 1300    female
# 1301      male
# 1302      male
# 1303      male
# 1304    female
# 1305    female
# ...

# %%
dummy_sex = pd.get_dummies(data["sex"], prefix="sex")

# %%
dummy_sex.head()
# Out:
#    sex_female  sex_male
# 0           1         0
# 1           0         1
# 2           1         0
# 3           0         1
# 4           1         0

# %%
column_name=data.columns.values.tolist()

# %%
column_name
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
data.drop(["sex"], axis = 1)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
pd.concat([data, dummy_sex], axis = 1)
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
def createDumies(df, var_name):
    dummy = pd.get_dummies(df[var_name], prefix= var_name)
    df = df.drop(var_name, axis = 1)
    df = pd.concat([df, dummy], axis = 1)
    return df

# %%
createDumies(data3, "sex")
# Out:
#       pclass  survived                                               name  \
# 0          1         1                      Allen, Miss. Elisabeth Walton
# 1          1         1                     Allison, Master. Hudson Trevor
# 2          1         0                       Allison, Miss. Helen Loraine
# 3          1         0               Allison, Mr. Hudson Joshua Creighton
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5          1         1                                Anderson, Mr. Harry
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 7          1         0                             Andrews, Mr. Thomas Jr
# 8          1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                            Artagaveytia, Mr. Ramon
# 10         1         0                             Astor, Col. John Jacob
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...
